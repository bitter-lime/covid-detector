# %%
import librosa
import librosa.display
import numpy as np

import warnings
warnings.filterwarnings ('ignore')

# %%
y, sr = librosa.load('/Users/home/Documents/Respiratory Illness AI/Official_dataset/copd/segmented_COPD1.wav', sr=347539)
copd = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=224)

copd.shape
librosa.display.specshow(copd, y_axis='mel', x_axis='time', sr=sr)

# %%
# Out:
# (224, 224)
